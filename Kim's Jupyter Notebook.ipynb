# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Kim's Jupyter Lab

# %% [markdown]
# ### Hey fellow aspiring Data Scientist, I'm Kim and I will strive to become the best Data Scientist I can be!

# %% [markdown]
# #### Here are some of the data languages that data scientist commonly uses:
#
# 1. Python
# 2. R
# 3. Java
# 4. SQL

# %% [markdown]
# #### Here are some of the data science libraries that data scientist commonly uses:
#
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn

# %% [markdown]
# | No | Data Science Tools |
# |:--------:|:--------:|
# | 1 | Apache Hadoop |
# | 2 | Apache Spark |
# | 3 | SAS |
# | 4 | Tableau |

# %% [markdown]
# ### Arithmetic Expression Evaluation

# %%
ari_eval = ( 2 * 3 ) + 5
ari_eval
# Out:
# 11

# %% [markdown]
# ### Multiplication and Add Integer

# %%
multi_add = ( 3 * 12 ) + 10
multi_add
# Out:
# 46

# %% [markdown]
# ### Convert Hours to Minutes

# %%
hours_per_day = 24
minutes_per_hour = 60

minutes_per_day = hours_per_day * minutes_per_hour
minutes_per_day
# Out:
# 1440

# %% [markdown]
# ### Objectives to Become a Data Scientist
#
# Here are some of my objective and goals achieve my dream to become a sucessful Data Scientist
#
# - Develop a curious personality
# - Develop a habit of continuous learning
# - Practice coding daily

# %% [markdown]
# ### Author Details
#
# #### Yap Kim Seong
# Aspiring Data Scientist

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
